# %% [markdown]
# # Argus image exploration from DUNEX

# %%
import pandas as pd
import cv2
import matplotlib.pyplot as plt

# %%
# Open the pickled data to see what is there
fname = '../microSWIFT_data/argus_images/mission_19_data/ArgusFF_20211008T140100Z_headerData.pickle'
obj = pd.read_pickle(fname)
obj.keys()
# Out:
# dict_keys(['captureArray', 'time', 'startSkipping', 'endSkipping', 'cams_all', 'totalCaptured', 'captures', 'missingFrames', 'beginGoodTimes', 'endGoodTimes'])

# %%
print(len(obj['time']))
print(len(obj['captures']))
print(len(obj['captureArray']))
# Out:
# 3840
# 2400
# 3840

# %%
print(obj['captures'][0])
# Out:
# [1.63370166e+09 1.63370166e+09 1.63370166e+09 1.63370166e+09]

# %% [markdown]
# I don't think any image data is contained in the header files - makes sense. But I think it does contain the time series info that we need to combine with the images stored in the avi file.
#
# Next lets look at the videos - what is contained in there and how can we read it in.

# %%
# read video
cap = cv2.VideoCapture('../microSWIFT_data/argus_images/mission_19_data/ArgusFF_20211008T140100Z_RectifiedVideo.avi')

ret, frame = cap.read()    
plt.figure()
plt.imshow(frame)

# %%
frame.shape
# Out:
# (1600, 500, 3)
